# %%
# imports

import numpy as np
import scipy.io as cpio
import os
import matplotlib.pyplot as plt
import glob
from sklearn.svm import SVC

# Work on all files
os.chdir('/Users/yardenc/Documents/Temp/SyllableSpects')
matfiles = glob.glob('*.mat')
numfiles = len(matfiles)
ErrMat = np.zeros((numfiles,numfiles))
for fnum0 in range(numfiles-1):
    for fnum1 in range(fnum0+1,numfiles):
        fname0 = matfiles[fnum0]
        fname1 = matfiles[fnum1]
        print('Comparing ' + fname0 + ' with ' + fname1)
        data0 = cpio.loadmat(fname0)
        data1 = cpio.loadmat(fname1)
        num_syls0 = len(data0['syllable_spects'][0][0][1])
        num_syls1 = len(data1['syllable_spects'][0][0][1])
        print('We have ' + str(num_syls0)  + ' syllables in the first class and ' + str(num_syls1) + 
              ' in the second class');

# Find max number of time bins in both classes and complete spectrograms by zero padding
# (keeping the spectrogram centered)
        max_bins0 = np.max([a[1] for a in[np.shape(data0['syllable_spects'][0][0][1][k][0]) 
                                  for k in range(num_syls0)]])
        max_bins1 = np.max([a[1] for a in[np.shape(data1['syllable_spects'][0][0][1][k][0]) 
                                  for k in range(num_syls1)]])
        max_bins = np.max([max_bins0, max_bins1]) 

        for sylcnt in range(num_syls0):
            [a,numbins] = np.shape(data0['syllable_spects'][0][0][1][sylcnt][0])
            bins_to_add = max_bins - numbins
            bins_before = bins_to_add/2
            bins_after = bins_to_add - bins_before
            data0['syllable_spects'][0][0][1][sylcnt][0] = np.concatenate(
                (np.zeros((513,bins_before)),
                data0['syllable_spects'][0][0][1][sylcnt][0],
                np.zeros((513,bins_after))),axis=1)
        for sylcnt in range(num_syls1):
            [a,numbins] = np.shape(data1['syllable_spects'][0][0][1][sylcnt][0])
            bins_to_add = max_bins - numbins
            bins_before = bins_to_add/2
            bins_after = bins_to_add - bins_before
            data1['syllable_spects'][0][0][1][sylcnt][0] = np.concatenate(
                (np.zeros((513,bins_before)),
                data1['syllable_spects'][0][0][1][sylcnt][0],
                np.zeros((513,bins_after))),axis=1)
        print('All spectrograms were zero padded to equally have ' + str(max_bins) + ' time bins.')        

# create training and testing sets by dividing the data into 2 equal sets
        X0 = [np.reshape(data0['syllable_spects'][0][0][1][k][0],(-1,)) for k in range(num_syls0)]
        X1 = [np.reshape(data1['syllable_spects'][0][0][1][k][0],(-1,)) for k in range(num_syls1)]
        Xtrain = np.concatenate((X0[0:num_syls0/2],X1[0:num_syls1/2]),axis=0)
        Xtest = np.concatenate((X0[num_syls0/2:],X1[num_syls1/2:]),axis=0)
        Ytrain = np.concatenate((np.ones((num_syls0/2,)),2*np.ones((num_syls1/2,))),axis=0)
        Ytest = np.concatenate((np.ones((num_syls0-num_syls0/2,)),
                        2*np.ones((num_syls1-num_syls1/2,))),axis=0)

# Train SVM classifier on data
        
        clf = SVC()
        clf.fit(Xtrain, Ytrain) 

# Show error rate
        err = np.abs(clf.predict(Xtest)-Ytest)
#plt.figure()
#plt.plot(err)
#plt.xlabel('syllable number')
#plt.ylabel('Error')
#plt.show()
        ErrMat[fnum0][fnum1] = np.mean(err)
        print('We get ' + str(np.sum(err)) + ' errors in a test set of ' + str(len(Ytest)) + ' syllables.')
        print('Error rate is: ' + str(np.mean(err)))
# Out:
# Comparing syllable_spects_8.mat with syllable_spects_9.mat
# We have 2024 syllables in the first class and 2020 in the second class
# All spectrograms were zero padded to equally have 18 time bins.
# We get 2.0 errors in a test set of 2022 syllables.
# Error rate is: 0.000989119683482
# Comparing syllable_spects_8.mat with syllable_spects_208.mat
# We have 2024 syllables in the first class and 2024 in the second class
# All spectrograms were zero padded to equally have 28 time bins.
# We get 0.0 errors in a test set of 2024 syllables.
# Error rate is: 0.0
# Comparing syllable_spects_8.mat with syllable_spects_308.mat
# We have 2024 syllables in the first class and 2013 in the second class
# All spectrograms were zero padded to equally have 41 time bins.
# We get 3.0 errors in a test set of 2019 syllables.
# Error rate is: 0.00148588410104
# Comparing syllable_spects_8.mat with syllable_spects_304.mat
# We have 2024 syllables in the first class and 2001 in the second class
# All spectrograms were zero padded to equally have 28 time bins.
# We get 3.0 errors in a test set of 2013 syllables.
# Error rate is: 0.00149031296572
# Comparing syllable_spects_8.mat with syllable_spects_305.mat
# We have 2024 syllables in the first class and 2005 in the second class
# All spectrograms were zero padded to equally have 24 time bins.
# We get 3.0 errors in a test set of 2015 syllables.
# Error rate is: 0.0014888337469
# Comparing syllable_spects_8.mat with syllable_spects_306.mat
# We have 2024 syllables in the first class and 2007 in the second class
# All spectrograms were zero padded to equally have 40 time bins.
# We get 4.0 errors in a test set of 2016 syllables.
# Error rate is: 0.00198412698413
# Comparing syllable_spects_8.mat with syllable_spects_500.mat
# We have 2024 syllables in the first class and 2014 in the second class
# All spectrograms were zero padded to equally have 47 time bins.
# We get 6.0 errors in a test set of 2019 syllables.
# Error rate is: 0.00297176820208
# Comparing syllable_spects_8.mat with syllable_spects_302.mat
# We have 2024 syllables in the first class and 1092 in the second class
# All spectrograms were zero padded to equally have 28 time bins.
# We get 0.0 errors in a test set of 1558 syllables.
# Error rate is: 0.0
# Comparing syllable_spects_8.mat with syllable_spects_303.mat
# We have 2024 syllables in the first class and 2010 in the second class
# All spectrograms were zero padded to equally have 29 time bins.
# We get 1.0 errors in a test set of 2017 syllables.
# Error rate is: 0.000495785820526
# Comparing syllable_spects_8.mat with syllable_spects_301.mat
# We have 2024 syllables in the first class and 2004 in the second class
# All spectrograms were zero padded to equally have 31 time bins.
# We get 2.0 errors in a test set of 2014 syllables.
# Error rate is: 0.000993048659384
# Comparing syllable_spects_8.mat with syllable_spects_300.mat
# We have 2024 syllables in the first class and 2018 in the second class
# All spectrograms were zero padded to equally have 36 time bins.
# We get 7.0 errors in a test set of 2021 syllables.
# Error rate is: 0.00346363186541
# Comparing syllable_spects_8.mat with syllable_spects_207.mat
# We have 2024 syllables in the first class and 2004 in the second class
# All spectrograms were zero padded to equally have 220 time bins.
# We get 10.0 errors in a test set of 2014 syllables.
# Error rate is: 0.00496524329692
# Comparing syllable_spects_8.mat with syllable_spects_2.mat
# We have 2024 syllables in the first class and 904 in the second class
# All spectrograms were zero padded to equally have 43 time bins.
# We get 6.0 errors in a test set of 1464 syllables.
# Error rate is: 0.00409836065574
# Comparing syllable_spects_8.mat with syllable_spects_401.mat
# We have 2024 syllables in the first class and 157 in the second class
# All spectrograms were zero padded to equally have 197 time bins.
# We get 2.0 errors in a test set of 1091 syllables.
# Error rate is: 0.00183318056829
# Comparing syllable_spects_8.mat with syllable_spects_400.mat
# We have 2024 syllables in the first class and 2004 in the second class
# All spectrograms were zero padded to equally have 45 time bins.
# We get 1.0 errors in a test set of 2014 syllables.
# Error rate is: 0.000496524329692
# Comparing syllable_spects_8.mat with syllable_spects_3.mat
# We have 2024 syllables in the first class and 2001 in the second class
# All spectrograms were zero padded to equally have 225 time bins.
# We get 25.0 errors in a test set of 2013 syllables.
# Error rate is: 0.0124192747144
# Comparing syllable_spects_8.mat with syllable_spects_206.mat
# We have 2024 syllables in the first class and 648 in the second class
# All spectrograms were zero padded to equally have 257 time bins.
# We get 2.0 errors in a test set of 1336 syllables.
# Error rate is: 0.00149700598802
# Comparing syllable_spects_8.mat with syllable_spects_204.mat
# We have 2024 syllables in the first class and 2017 in the second class
# All spectrograms were zero padded to equally have 42 time bins.
# We get 4.0 errors in a test set of 2021 syllables.
# Error rate is: 0.00197921820881
# Comparing syllable_spects_8.mat with syllable_spects_1.mat
# We have 2024 syllables in the first class and 1678 in the second class
# All spectrograms were zero padded to equally have 18 time bins.
# We get 5.0 errors in a test set of 1851 syllables.
# Error rate is: 0.00270124257158
# Comparing syllable_spects_8.mat with syllable_spects_0.mat
# We have 2024 syllables in the first class and 2009 in the second class
# All spectrograms were zero padded to equally have 21 time bins.
# We get 3.0 errors in a test set of 2017 syllables.
# Error rate is: 0.00148735746158
# Comparing syllable_spects_8.mat with syllable_spects_205.mat
# We have 2024 syllables in the first class and 2001 in the second class
# All spectrograms were zero padded to equally have 225 time bins.
# We get 33.0 errors in a test set of 2013 syllables.
# Error rate is: 0.016393442623
# Comparing syllable_spects_8.mat with syllable_spects_201.mat
# We have 2024 syllables in the first class and 2001 in the second class
# All spectrograms were zero padded to equally have 306 time bins.
# We get 8.0 errors in a test set of 2013 syllables.
# Error rate is: 0.00397416790859
# Comparing syllable_spects_8.mat with syllable_spects_4.mat
# We have 2024 syllables in the first class and 2000 in the second class
# All spectrograms were zero padded to equally have 17 time bins.
# We get 93.0 errors in a test set of 2012 syllables.
# Error rate is: 0.0462226640159
# Comparing syllable_spects_8.mat with syllable_spects_5.mat
# We have 2024 syllables in the first class and 2005 in the second class
# All spectrograms were zero padded to equally have 38 time bins.
# We get 12.0 errors in a test set of 2015 syllables.
# Error rate is: 0.00595533498759
# Comparing syllable_spects_8.mat with syllable_spects_200.mat
# We have 2024 syllables in the first class and 2035 in the second class
# All spectrograms were zero padded to equally have 40 time bins.
# We get 3.0 errors in a test set of 2030 syllables.
# Error rate is: 0.00147783251232
# Comparing syllable_spects_8.mat with syllable_spects_7.mat
# We have 2024 syllables in the first class and 2001 in the second class
# All spectrograms were zero padded to equally have 120 time bins.
# We get 16.0 errors in a test set of 2013 syllables.
# Error rate is: 0.00794833581719
# Comparing syllable_spects_8.mat with syllable_spects_404.mat
# We have 2024 syllables in the first class and 1089 in the second class
# All spectrograms were zero padded to equally have 199 time bins.
# We get 8.0 errors in a test set of 1557 syllables.
# Error rate is: 0.00513808606294
# Comparing syllable_spects_8.mat with syllable_spects_6.mat
# We have 2024 syllables in the first class and 2000 in the second class
# All spectrograms were zero padded to equally have 176 time bins.
# We get 76.0 errors in a test set of 2012 syllables.
# Error rate is: 0.037773359841
# Comparing syllable_spects_8.mat with syllable_spects_203.mat
# We have 2024 syllables in the first class and 2004 in the second class
# All spectrograms were zero padded to equally have 27 time bins.
# We get 13.0 errors in a test set of 2014 syllables.
# Error rate is: 0.006454816286
# Comparing syllable_spects_9.mat with syllable_spects_208.mat
# We have 2020 syllables in the first class and 2024 in the second class
# All spectrograms were zero padded to equally have 28 time bins.
# We get 0.0 errors in a test set of 2022 syllables.
# Error rate is: 0.0
# Comparing syllable_spects_9.mat with syllable_spects_308.mat
# We have 2020 syllables in the first class and 2013 in the second class
# All spectrograms were zero padded to equally have 41 time bins.
# We get 2.0 errors in a test set of 2017 syllables.
# Error rate is: 0.000991571641051
# Comparing syllable_spects_9.mat with syllable_spects_304.mat
# We have 2020 syllables in the first class and 2001 in the second class
# All spectrograms were zero padded to equally have 28 time bins.
# We get 1.0 errors in a test set of 2011 syllables.
# Error rate is: 0.000497265042268
# Comparing syllable_spects_9.mat with syllable_spects_305.mat
# We have 2020 syllables in the first class and 2005 in the second class
# All spectrograms were zero padded to equally have 24 time bins.
# We get 3.0 errors in a test set of 2013 syllables.
# Error rate is: 0.00149031296572
# Comparing syllable_spects_9.mat with syllable_spects_306.mat
# We have 2020 syllables in the first class and 2007 in the second class
# All spectrograms were zero padded to equally have 40 time bins.
# We get 2.0 errors in a test set of 2014 syllables.
# Error rate is: 0.000993048659384
# Comparing syllable_spects_9.mat with syllable_spects_500.mat
# We have 2020 syllables in the first class and 2014 in the second class
# All spectrograms were zero padded to equally have 47 time bins.
# We get 5.0 errors in a test set of 2017 syllables.
# Error rate is: 0.00247892910263
# Comparing syllable_spects_9.mat with syllable_spects_302.mat
# We have 2020 syllables in the first class and 1092 in the second class
# All spectrograms were zero padded to equally have 28 time bins.
# We get 0.0 errors in a test set of 1556 syllables.
# Error rate is: 0.0
# Comparing syllable_spects_9.mat with syllable_spects_303.mat
# We have 2020 syllables in the first class and 2010 in the second class
# All spectrograms were zero padded to equally have 29 time bins.
# We get 0.0 errors in a test set of 2015 syllables.
# Error rate is: 0.0
# Comparing syllable_spects_9.mat with syllable_spects_301.mat
# We have 2020 syllables in the first class and 2004 in the second class
# All spectrograms were zero padded to equally have 31 time bins.
# We get 4.0 errors in a test set of 2012 syllables.
# Error rate is: 0.00198807157058
# Comparing syllable_spects_9.mat with syllable_spects_300.mat
# We have 2020 syllables in the first class and 2018 in the second class
# All spectrograms were zero padded to equally have 36 time bins.
# We get 3.0 errors in a test set of 2019 syllables.
# Error rate is: 0.00148588410104
# Comparing syllable_spects_9.mat with syllable_spects_207.mat
# We have 2020 syllables in the first class and 2004 in the second class
# All spectrograms were zero padded to equally have 220 time bins.
# We get 10.0 errors in a test set of 2012 syllables.
# Error rate is: 0.00497017892644
# Comparing syllable_spects_9.mat with syllable_spects_2.mat
# We have 2020 syllables in the first class and 904 in the second class
# All spectrograms were zero padded to equally have 43 time bins.
# We get 0.0 errors in a test set of 1462 syllables.
# Error rate is: 0.0
# Comparing syllable_spects_9.mat with syllable_spects_401.mat
# We have 2020 syllables in the first class and 157 in the second class
# All spectrograms were zero padded to equally have 197 time bins.
# We get 2.0 errors in a test set of 1089 syllables.
# Error rate is: 0.00183654729109
# Comparing syllable_spects_9.mat with syllable_spects_400.mat
# We have 2020 syllables in the first class and 2004 in the second class
# All spectrograms were zero padded to equally have 45 time bins.
# We get 1.0 errors in a test set of 2012 syllables.
# Error rate is: 0.000497017892644
# Comparing syllable_spects_9.mat with syllable_spects_3.mat
# We have 2020 syllables in the first class and 2001 in the second class
# All spectrograms were zero padded to equally have 225 time bins.
# We get 25.0 errors in a test set of 2011 syllables.
# Error rate is: 0.0124316260567
# Comparing syllable_spects_9.mat with syllable_spects_206.mat
# We have 2020 syllables in the first class and 648 in the second class
# All spectrograms were zero padded to equally have 257 time bins.
# We get 2.0 errors in a test set of 1334 syllables.
# Error rate is: 0.00149925037481
# Comparing syllable_spects_9.mat with syllable_spects_204.mat
# We have 2020 syllables in the first class and 2017 in the second class
# All spectrograms were zero padded to equally have 42 time bins.
# We get 3.0 errors in a test set of 2019 syllables.
# Error rate is: 0.00148588410104
# Comparing syllable_spects_9.mat with syllable_spects_1.mat
# We have 2020 syllables in the first class and 1678 in the second class
# All spectrograms were zero padded to equally have 18 time bins.
# We get 0.0 errors in a test set of 1849 syllables.
# Error rate is: 0.0
# Comparing syllable_spects_9.mat with syllable_spects_0.mat
# We have 2020 syllables in the first class and 2009 in the second class
# All spectrograms were zero padded to equally have 21 time bins.
# We get 73.0 errors in a test set of 2015 syllables.
# Error rate is: 0.0362282878412
# Comparing syllable_spects_9.mat with syllable_spects_205.mat
# We have 2020 syllables in the first class and 2001 in the second class
# All spectrograms were zero padded to equally have 225 time bins.
# We get 32.0 errors in a test set of 2011 syllables.
# Error rate is: 0.0159124813526
# Comparing syllable_spects_9.mat with syllable_spects_201.mat
# We have 2020 syllables in the first class and 2001 in the second class
# All spectrograms were zero padded to equally have 306 time bins.
# We get 6.0 errors in a test set of 2011 syllables.
# Error rate is: 0.00298359025361
# Comparing syllable_spects_9.mat with syllable_spects_4.mat
# We have 2020 syllables in the first class and 2000 in the second class
# All spectrograms were zero padded to equally have 18 time bins.
# We get 1.0 errors in a test set of 2010 syllables.
# Error rate is: 0.000497512437811
# Comparing syllable_spects_9.mat with syllable_spects_5.mat
# We have 2020 syllables in the first class and 2005 in the second class
# All spectrograms were zero padded to equally have 38 time bins.
# We get 0.0 errors in a test set of 2013 syllables.
# Error rate is: 0.0
# Comparing syllable_spects_9.mat with syllable_spects_200.mat
# We have 2020 syllables in the first class and 2035 in the second class
# All spectrograms were zero padded to equally have 40 time bins.
# We get 1.0 errors in a test set of 2028 syllables.
# Error rate is: 0.000493096646943
# Comparing syllable_spects_9.mat with syllable_spects_7.mat
# We have 2020 syllables in the first class and 2001 in the second class
# All spectrograms were zero padded to equally have 120 time bins.
# We get 15.0 errors in a test set of 2011 syllables.
# Error rate is: 0.00745897563401
# Comparing syllable_spects_9.mat with syllable_spects_404.mat
# We have 2020 syllables in the first class and 1089 in the second class
# All spectrograms were zero padded to equally have 199 time bins.
# We get 9.0 errors in a test set of 1555 syllables.
# Error rate is: 0.00578778135048
# Comparing syllable_spects_9.mat with syllable_spects_6.mat
# We have 2020 syllables in the first class and 2000 in the second class
# All spectrograms were zero padded to equally have 176 time bins.
# We get 2.0 errors in a test set of 2010 syllables.
# Error rate is: 0.000995024875622
# Comparing syllable_spects_9.mat with syllable_spects_203.mat
# We have 2020 syllables in the first class and 2004 in the second class
# All spectrograms were zero padded to equally have 27 time bins.
# We get 0.0 errors in a test set of 2012 syllables.
# Error rate is: 0.0
# Comparing syllable_spects_208.mat with syllable_spects_308.mat
# We have 2024 syllables in the first class and 2013 in the second class
# All spectrograms were zero padded to equally have 41 time bins.
# We get 20.0 errors in a test set of 2019 syllables.
# Error rate is: 0.00990589400693
# Comparing syllable_spects_208.mat with syllable_spects_304.mat
# We have 2024 syllables in the first class and 2001 in the second class
# All spectrograms were zero padded to equally have 28 time bins.
# We get 4.0 errors in a test set of 2013 syllables.
# Error rate is: 0.0019870839543
# Comparing syllable_spects_208.mat with syllable_spects_305.mat
# We have 2024 syllables in the first class and 2005 in the second class
# All spectrograms were zero padded to equally have 28 time bins.
# We get 3.0 errors in a test set of 2015 syllables.
# Error rate is: 0.0014888337469
# Comparing syllable_spects_208.mat with syllable_spects_306.mat
# We have 2024 syllables in the first class and 2007 in the second class
# All spectrograms were zero padded to equally have 40 time bins.
# We get 8.0 errors in a test set of 2016 syllables.
# Error rate is: 0.00396825396825
# Comparing syllable_spects_208.mat with syllable_spects_500.mat
# We have 2024 syllables in the first class and 2014 in the second class
# All spectrograms were zero padded to equally have 47 time bins.
# We get 14.0 errors in a test set of 2019 syllables.
# Error rate is: 0.00693412580485
# Comparing syllable_spects_208.mat with syllable_spects_302.mat
# We have 2024 syllables in the first class and 1092 in the second class
# All spectrograms were zero padded to equally have 28 time bins.
# We get 0.0 errors in a test set of 1558 syllables.
# Error rate is: 0.0
# Comparing syllable_spects_208.mat with syllable_spects_303.mat
# We have 2024 syllables in the first class and 2010 in the second class
# All spectrograms were zero padded to equally have 29 time bins.
# We get 1.0 errors in a test set of 2017 syllables.
# Error rate is: 0.000495785820526
# Comparing syllable_spects_208.mat with syllable_spects_301.mat
# We have 2024 syllables in the first class and 2004 in the second class
# All spectrograms were zero padded to equally have 31 time bins.
# We get 0.0 errors in a test set of 2014 syllables.
# Error rate is: 0.0
# Comparing syllable_spects_208.mat with syllable_spects_300.mat
# We have 2024 syllables in the first class and 2018 in the second class
# All spectrograms were zero padded to equally have 36 time bins.
# We get 8.0 errors in a test set of 2021 syllables.
# Error rate is: 0.00395843641762
# Comparing syllable_spects_208.mat with syllable_spects_207.mat
# We have 2024 syllables in the first class and 2004 in the second class
# All spectrograms were zero padded to equally have 220 time bins.
# We get 11.0 errors in a test set of 2014 syllables.
# Error rate is: 0.00546176762661
# Comparing syllable_spects_208.mat with syllable_spects_2.mat
# We have 2024 syllables in the first class and 904 in the second class
# All spectrograms were zero padded to equally have 43 time bins.
# We get 0.0 errors in a test set of 1464 syllables.
# Error rate is: 0.0
# Comparing syllable_spects_208.mat with syllable_spects_401.mat
# We have 2024 syllables in the first class and 157 in the second class
# All spectrograms were zero padded to equally have 197 time bins.
# We get 2.0 errors in a test set of 1091 syllables.
# Error rate is: 0.00183318056829
# Comparing syllable_spects_208.mat with syllable_spects_400.mat
# We have 2024 syllables in the first class and 2004 in the second class
# All spectrograms were zero padded to equally have 45 time bins.
# We get 1.0 errors in a test set of 2014 syllables.
# Error rate is: 0.000496524329692
# Comparing syllable_spects_208.mat with syllable_spects_3.mat
# We have 2024 syllables in the first class and 2001 in the second class
# All spectrograms were zero padded to equally have 225 time bins.
# We get 27.0 errors in a test set of 2013 syllables.
# Error rate is: 0.0134128166915
# Comparing syllable_spects_208.mat with syllable_spects_206.mat
# We have 2024 syllables in the first class and 648 in the second class
# All spectrograms were zero padded to equally have 257 time bins.
# We get 2.0 errors in a test set of 1336 syllables.
# Error rate is: 0.00149700598802
# Comparing syllable_spects_208.mat with syllable_spects_204.mat
# We have 2024 syllables in the first class and 2017 in the second class
# All spectrograms were zero padded to equally have 42 time bins.
# We get 0.0 errors in a test set of 2021 syllables.
# Error rate is: 0.0
# Comparing syllable_spects_208.mat with syllable_spects_1.mat
# We have 2024 syllables in the first class and 1678 in the second class
# All spectrograms were zero padded to equally have 28 time bins.
# We get 0.0 errors in a test set of 1851 syllables.
# Error rate is: 0.0
# Comparing syllable_spects_208.mat with syllable_spects_0.mat
# We have 2024 syllables in the first class and 2009 in the second class
# All spectrograms were zero padded to equally have 28 time bins.
# We get 3.0 errors in a test set of 2017 syllables.
# Error rate is: 0.00148735746158
# Comparing syllable_spects_208.mat with syllable_spects_205.mat
# We have 2024 syllables in the first class and 2001 in the second class
# All spectrograms were zero padded to equally have 225 time bins.
# We get 32.0 errors in a test set of 2013 syllables.
# Error rate is: 0.0158966716344
# Comparing syllable_spects_208.mat with syllable_spects_201.mat
# We have 2024 syllables in the first class and 2001 in the second class
# All spectrograms were zero padded to equally have 306 time bins.
# We get 9.0 errors in a test set of 2013 syllables.
# Error rate is: 0.00447093889717
# Comparing syllable_spects_208.mat with syllable_spects_4.mat
# We have 2024 syllables in the first class and 2000 in the second class
# All spectrograms were zero padded to equally have 28 time bins.
# We get 0.0 errors in a test set of 2012 syllables.
# Error rate is: 0.0
# Comparing syllable_spects_208.mat with syllable_spects_5.mat
# We have 2024 syllables in the first class and 2005 in the second class
# All spectrograms were zero padded to equally have 38 time bins.
# We get 20.0 errors in a test set of 2015 syllables.
# Error rate is: 0.00992555831266
# Comparing syllable_spects_208.mat with syllable_spects_200.mat
# We have 2024 syllables in the first class and 2035 in the second class
# All spectrograms were zero padded to equally have 40 time bins.
# We get 0.0 errors in a test set of 2030 syllables.
# Error rate is: 0.0
# Comparing syllable_spects_208.mat with syllable_spects_7.mat
# We have 2024 syllables in the first class and 2001 in the second class
# All spectrograms were zero padded to equally have 120 time bins.
# We get 14.0 errors in a test set of 2013 syllables.
# Error rate is: 0.00695479384004
# Comparing syllable_spects_208.mat with syllable_spects_404.mat
# We have 2024 syllables in the first class and 1089 in the second class
# All spectrograms were zero padded to equally have 199 time bins.
# We get 10.0 errors in a test set of 1557 syllables.
# Error rate is: 0.00642260757868
# Comparing syllable_spects_208.mat with syllable_spects_6.mat
# We have 2024 syllables in the first class and 2000 in the second class
# All spectrograms were zero padded to equally have 176 time bins.
# We get 18.0 errors in a test set of 2012 syllables.
# Error rate is: 0.00894632206759
# Comparing syllable_spects_208.mat with syllable_spects_203.mat
# We have 2024 syllables in the first class and 2004 in the second class
# All spectrograms were zero padded to equally have 28 time bins.
# We get 0.0 errors in a test set of 2014 syllables.
# Error rate is: 0.0
# Comparing syllable_spects_308.mat with syllable_spects_304.mat
# We have 2013 syllables in the first class and 2001 in the second class
# All spectrograms were zero padded to equally have 41 time bins.
# We get 7.0 errors in a test set of 2008 syllables.
# Error rate is: 0.00348605577689
# Comparing syllable_spects_308.mat with syllable_spects_305.mat
# We have 2013 syllables in the first class and 2005 in the second class
# All spectrograms were zero padded to equally have 41 time bins.
# We get 5.0 errors in a test set of 2010 syllables.
# Error rate is: 0.00248756218905
# Comparing syllable_spects_308.mat with syllable_spects_306.mat
# We have 2013 syllables in the first class and 2007 in the second class
# All spectrograms were zero padded to equally have 41 time bins.
# We get 17.0 errors in a test set of 2011 syllables.
# Error rate is: 0.00845350571855
# Comparing syllable_spects_308.mat with syllable_spects_500.mat
# We have 2013 syllables in the first class and 2014 in the second class
# All spectrograms were zero padded to equally have 47 time bins.
# We get 9.0 errors in a test set of 2014 syllables.
# Error rate is: 0.00446871896723
# Comparing syllable_spects_308.mat with syllable_spects_302.mat
# We have 2013 syllables in the first class and 1092 in the second class
# All spectrograms were zero padded to equally have 41 time bins.
# We get 0.0 errors in a test set of 1553 syllables.
# Error rate is: 0.0
# Comparing syllable_spects_308.mat with syllable_spects_303.mat
# We have 2013 syllables in the first class and 2010 in the second class
# All spectrograms were zero padded to equally have 41 time bins.
# We get 3.0 errors in a test set of 2012 syllables.
# Error rate is: 0.00149105367793
# Comparing syllable_spects_308.mat with syllable_spects_301.mat
# We have 2013 syllables in the first class and 2004 in the second class
# All spectrograms were zero padded to equally have 41 time bins.
# We get 4.0 errors in a test set of 2009 syllables.
# Error rate is: 0.00199104031857
# Comparing syllable_spects_308.mat with syllable_spects_300.mat
# We have 2013 syllables in the first class and 2018 in the second class
# All spectrograms were zero padded to equally have 41 time bins.
# We get 15.0 errors in a test set of 2016 syllables.
# Error rate is: 0.00744047619048
# Comparing syllable_spects_308.mat with syllable_spects_207.mat
# We have 2013 syllables in the first class and 2004 in the second class
# All spectrograms were zero padded to equally have 220 time bins.
# We get 12.0 errors in a test set of 2009 syllables.
# Error rate is: 0.0059731209557
# Comparing syllable_spects_308.mat with syllable_spects_2.mat
# We have 2013 syllables in the first class and 904 in the second class
# All spectrograms were zero padded to equally have 43 time bins.
# We get 3.0 errors in a test set of 1459 syllables.
# Error rate is: 0.00205620287868
# Comparing syllable_spects_308.mat with syllable_spects_401.mat
# We have 2013 syllables in the first class and 157 in the second class
# All spectrograms were zero padded to equally have 197 time bins.
# We get 3.0 errors in a test set of 1086 syllables.
# Error rate is: 0.00276243093923
# Comparing syllable_spects_308.mat with syllable_spects_400.mat
# We have 2013 syllables in the first class and 2004 in the second class
# All spectrograms were zero padded to equally have 45 time bins.
# We get 1.0 errors in a test set of 2009 syllables.
# Error rate is: 0.000497760079642
# Comparing syllable_spects_308.mat with syllable_spects_3.mat
# We have 2013 syllables in the first class and 2001 in the second class
# All spectrograms were zero padded to equally have 225 time bins.
# We get 27.0 errors in a test set of 2008 syllables.
# Error rate is: 0.0134462151394
# Comparing syllable_spects_308.mat with syllable_spects_206.mat
# We have 2013 syllables in the first class and 648 in the second class
# All spectrograms were zero padded to equally have 257 time bins.
# We get 2.0 errors in a test set of 1331 syllables.
# Error rate is: 0.0015026296018
# Comparing syllable_spects_308.mat with syllable_spects_204.mat
# We have 2013 syllables in the first class and 2017 in the second class
# All spectrograms were zero padded to equally have 42 time bins.
# We get 3.0 errors in a test set of 2016 syllables.
# Error rate is: 0.0014880952381
# Comparing syllable_spects_308.mat with syllable_spects_1.mat
# We have 2013 syllables in the first class and 1678 in the second class
# All spectrograms were zero padded to equally have 41 time bins.
# We get 3.0 errors in a test set of 1846 syllables.
# Error rate is: 0.00162513542795
# Comparing syllable_spects_308.mat with syllable_spects_0.mat
# We have 2013 syllables in the first class and 2009 in the second class
# All spectrograms were zero padded to equally have 41 time bins.
# We get 3.0 errors in a test set of 2012 syllables.
# Error rate is: 0.00149105367793
# Comparing syllable_spects_308.mat with syllable_spects_205.mat
# We have 2013 syllables in the first class and 2001 in the second class
# All spectrograms were zero padded to equally have 225 time bins.
# We get 38.0 errors in a test set of 2008 syllables.
# Error rate is: 0.0189243027888
# Comparing syllable_spects_308.mat with syllable_spects_201.mat
# We have 2013 syllables in the first class and 2001 in the second class
# All spectrograms were zero padded to equally have 306 time bins.
# We get 10.0 errors in a test set of 2008 syllables.
# Error rate is: 0.00498007968127
# Comparing syllable_spects_308.mat with syllable_spects_4.mat
# We have 2013 syllables in the first class and 2000 in the second class
# All spectrograms were zero padded to equally have 41 time bins.
# We get 23.0 errors in a test set of 2007 syllables.
# Error rate is: 0.0114598903837
# Comparing syllable_spects_308.mat with syllable_spects_5.mat
# We have 2013 syllables in the first class and 2005 in the second class
# All spectrograms were zero padded to equally have 41 time bins.
# We get 81.0 errors in a test set of 2010 syllables.
# Error rate is: 0.0402985074627
# Comparing syllable_spects_308.mat with syllable_spects_200.mat
# We have 2013 syllables in the first class and 2035 in the second class
# All spectrograms were zero padded to equally have 41 time bins.
# We get 6.0 errors in a test set of 2025 syllables.
# Error rate is: 0.00296296296296
# Comparing syllable_spects_308.mat with syllable_spects_7.mat
# We have 2013 syllables in the first class and 2001 in the second class
# All spectrograms were zero padded to equally have 120 time bins.
# We get 22.0 errors in a test set of 2008 syllables.
# Error rate is: 0.0109561752988
# Comparing syllable_spects_308.mat with syllable_spects_404.mat
# We have 2013 syllables in the first class and 1089 in the second class
# All spectrograms were zero padded to equally have 199 time bins.
# We get 9.0 errors in a test set of 1552 syllables.
# Error rate is: 0.00579896907216
# Comparing syllable_spects_308.mat with syllable_spects_6.mat
# We have 2013 syllables in the first class and 2000 in the second class
# All spectrograms were zero padded to equally have 176 time bins.
# We get 89.0 errors in a test set of 2007 syllables.
# Error rate is: 0.0443447932237
# Comparing syllable_spects_308.mat with syllable_spects_203.mat
# We have 2013 syllables in the first class and 2004 in the second class
# All spectrograms were zero padded to equally have 41 time bins.
# We get 7.0 errors in a test set of 2009 syllables.
# Error rate is: 0.00348432055749
# Comparing syllable_spects_304.mat with syllable_spects_305.mat
# We have 2001 syllables in the first class and 2005 in the second class
# All spectrograms were zero padded to equally have 28 time bins.
# We get 5.0 errors in a test set of 2004 syllables.
# Error rate is: 0.00249500998004
# Comparing syllable_spects_304.mat with syllable_spects_306.mat
# We have 2001 syllables in the first class and 2007 in the second class
# All spectrograms were zero padded to equally have 40 time bins.
# We get 5.0 errors in a test set of 2005 syllables.
# Error rate is: 0.00249376558603
# Comparing syllable_spects_304.mat with syllable_spects_500.mat
# We have 2001 syllables in the first class and 2014 in the second class
# All spectrograms were zero padded to equally have 47 time bins.
# We get 6.0 errors in a test set of 2008 syllables.
# Error rate is: 0.00298804780876
# Comparing syllable_spects_304.mat with syllable_spects_302.mat
# We have 2001 syllables in the first class and 1092 in the second class
# All spectrograms were zero padded to equally have 28 time bins.
# We get 0.0 errors in a test set of 1547 syllables.
# Error rate is: 0.0
# Comparing syllable_spects_304.mat with syllable_spects_303.mat
# We have 2001 syllables in the first class and 2010 in the second class
# All spectrograms were zero padded to equally have 29 time bins.
# We get 5.0 errors in a test set of 2006 syllables.
# Error rate is: 0.0024925224327
# Comparing syllable_spects_304.mat with syllable_spects_301.mat
# We have 2001 syllables in the first class and 2004 in the second class
# All spectrograms were zero padded to equally have 31 time bins.
# We get 1.0 errors in a test set of 2003 syllables.
# Error rate is: 0.000499251123315
# Comparing syllable_spects_304.mat with syllable_spects_300.mat
# We have 2001 syllables in the first class and 2018 in the second class
# All spectrograms were zero padded to equally have 36 time bins.
# We get 5.0 errors in a test set of 2010 syllables.
# Error rate is: 0.00248756218905
# Comparing syllable_spects_304.mat with syllable_spects_207.mat
# We have 2001 syllables in the first class and 2004 in the second class
# All spectrograms were zero padded to equally have 220 time bins.
# We get 11.0 errors in a test set of 2003 syllables.
# Error rate is: 0.00549176235647
# Comparing syllable_spects_304.mat with syllable_spects_2.mat
# We have 2001 syllables in the first class and 904 in the second class
# All spectrograms were zero padded to equally have 43 time bins.
# We get 1.0 errors in a test set of 1453 syllables.
# Error rate is: 0.000688231245699
# Comparing syllable_spects_304.mat with syllable_spects_401.mat
# We have 2001 syllables in the first class and 157 in the second class
# All spectrograms were zero padded to equally have 197 time bins.
# We get 2.0 errors in a test set of 1080 syllables.
# Error rate is: 0.00185185185185
# Comparing syllable_spects_304.mat with syllable_spects_400.mat
# We have 2001 syllables in the first class and 2004 in the second class
# All spectrograms were zero padded to equally have 45 time bins.
# We get 1.0 errors in a test set of 2003 syllables.
# Error rate is: 0.000499251123315
# Comparing syllable_spects_304.mat with syllable_spects_3.mat
# We have 2001 syllables in the first class and 2001 in the second class
# All spectrograms were zero padded to equally have 225 time bins.
# We get 27.0 errors in a test set of 2002 syllables.
# Error rate is: 0.0134865134865
# Comparing syllable_spects_304.mat with syllable_spects_206.mat
# We have 2001 syllables in the first class and 648 in the second class
# All spectrograms were zero padded to equally have 257 time bins.
# We get 2.0 errors in a test set of 1325 syllables.
# Error rate is: 0.00150943396226
# Comparing syllable_spects_304.mat with syllable_spects_204.mat
# We have 2001 syllables in the first class and 2017 in the second class
# All spectrograms were zero padded to equally have 42 time bins.
# We get 3.0 errors in a test set of 2010 syllables.
# Error rate is: 0.00149253731343
# Comparing syllable_spects_304.mat with syllable_spects_1.mat
# We have 2001 syllables in the first class and 1678 in the second class
# All spectrograms were zero padded to equally have 28 time bins.
# We get 2.0 errors in a test set of 1840 syllables.
# Error rate is: 0.00108695652174
# Comparing syllable_spects_304.mat with syllable_spects_0.mat
# We have 2001 syllables in the first class and 2009 in the second class
# All spectrograms were zero padded to equally have 28 time bins.
# We get 2.0 errors in a test set of 2006 syllables.
# Error rate is: 0.000997008973081
# Comparing syllable_spects_304.mat with syllable_spects_205.mat
# We have 2001 syllables in the first class and 2001 in the second class
# All spectrograms were zero padded to equally have 225 time bins.
# We get 33.0 errors in a test set of 2002 syllables.
# Error rate is: 0.0164835164835
# Comparing syllable_spects_304.mat with syllable_spects_201.mat
# We have 2001 syllables in the first class and 2001 in the second class
# All spectrograms were zero padded to equally have 306 time bins.
# We get 10.0 errors in a test set of 2002 syllables.
# Error rate is: 0.004995004995
# Comparing syllable_spects_304.mat with syllable_spects_4.mat
# We have 2001 syllables in the first class and 2000 in the second class
# All spectrograms were zero padded to equally have 28 time bins.
# We get 4.0 errors in a test set of 2001 syllables.
# Error rate is: 0.00199900049975
# Comparing syllable_spects_304.mat with syllable_spects_5.mat
# We have 2001 syllables in the first class and 2005 in the second class
# All spectrograms were zero padded to equally have 38 time bins.
# We get 19.0 errors in a test set of 2004 syllables.
# Error rate is: 0.00948103792415
# Comparing syllable_spects_304.mat with syllable_spects_200.mat
# We have 2001 syllables in the first class and 2035 in the second class
# All spectrograms were zero padded to equally have 40 time bins.
# We get 14.0 errors in a test set of 2019 syllables.
# Error rate is: 0.00693412580485
# Comparing syllable_spects_304.mat with syllable_spects_7.mat
# We have 2001 syllables in the first class and 2001 in the second class
# All spectrograms were zero padded to equally have 120 time bins.
# We get 19.0 errors in a test set of 2002 syllables.
# Error rate is: 0.00949050949051
# Comparing syllable_spects_304.mat with syllable_spects_404.mat
# We have 2001 syllables in the first class and 1089 in the second class
# All spectrograms were zero padded to equally have 199 time bins.
# We get 9.0 errors in a test set of 1546 syllables.
# Error rate is: 0.00582147477361
# Comparing syllable_spects_304.mat with syllable_spects_6.mat
# We have 2001 syllables in the first class and 2000 in the second class
# All spectrograms were zero padded to equally have 176 time bins.
# We get 43.0 errors in a test set of 2001 syllables.
# Error rate is: 0.0214892553723
# Comparing syllable_spects_304.mat with syllable_spects_203.mat
# We have 2001 syllables in the first class and 2004 in the second class
# All spectrograms were zero padded to equally have 28 time bins.
# We get 1.0 errors in a test set of 2003 syllables.
# Error rate is: 0.000499251123315
# Comparing syllable_spects_305.mat with syllable_spects_306.mat
# We have 2005 syllables in the first class and 2007 in the second class
# All spectrograms were zero padded to equally have 40 time bins.
# We get 3.0 errors in a test set of 2007 syllables.
# Error rate is: 0.00149476831091
# Comparing syllable_spects_305.mat with syllable_spects_500.mat
# We have 2005 syllables in the first class and 2014 in the second class
# All spectrograms were zero padded to equally have 47 time bins.
# We get 12.0 errors in a test set of 2010 syllables.
# Error rate is: 0.00597014925373
# Comparing syllable_spects_305.mat with syllable_spects_302.mat
# We have 2005 syllables in the first class and 1092 in the second class
# All spectrograms were zero padded to equally have 28 time bins.
# We get 1.0 errors in a test set of 1549 syllables.
# Error rate is: 0.000645577792124
# Comparing syllable_spects_305.mat with syllable_spects_303.mat
# We have 2005 syllables in the first class and 2010 in the second class
# All spectrograms were zero padded to equally have 29 time bins.
# We get 2.0 errors in a test set of 2008 syllables.
# Error rate is: 0.000996015936255
# Comparing syllable_spects_305.mat with syllable_spects_301.mat
# We have 2005 syllables in the first class and 2004 in the second class
# All spectrograms were zero padded to equally have 31 time bins.
# We get 2.0 errors in a test set of 2005 syllables.
# Error rate is: 0.000997506234414
# Comparing syllable_spects_305.mat with syllable_spects_300.mat
# We have 2005 syllables in the first class and 2018 in the second class
# All spectrograms were zero padded to equally have 36 time bins.
# We get 5.0 errors in a test set of 2012 syllables.
# Error rate is: 0.00248508946322
# Comparing syllable_spects_305.mat with syllable_spects_207.mat
# We have 2005 syllables in the first class and 2004 in the second class
# All spectrograms were zero padded to equally have 220 time bins.
# We get 11.0 errors in a test set of 2005 syllables.
# Error rate is: 0.00548628428928
# Comparing syllable_spects_305.mat with syllable_spects_2.mat
# We have 2005 syllables in the first class and 904 in the second class
# All spectrograms were zero padded to equally have 43 time bins.
# We get 5.0 errors in a test set of 1455 syllables.
# Error rate is: 0.00343642611684
# Comparing syllable_spects_305.mat with syllable_spects_401.mat
# We have 2005 syllables in the first class and 157 in the second class
# All spectrograms were zero padded to equally have 197 time bins.
# We get 2.0 errors in a test set of 1082 syllables.
# Error rate is: 0.00184842883549
# Comparing syllable_spects_305.mat with syllable_spects_400.mat
# We have 2005 syllables in the first class and 2004 in the second class
# All spectrograms were zero padded to equally have 45 time bins.
# We get 1.0 errors in a test set of 2005 syllables.
# Error rate is: 0.000498753117207
# Comparing syllable_spects_305.mat with syllable_spects_3.mat
# We have 2005 syllables in the first class and 2001 in the second class
# All spectrograms were zero padded to equally have 225 time bins.
# We get 27.0 errors in a test set of 2004 syllables.
# Error rate is: 0.0134730538922
# Comparing syllable_spects_305.mat with syllable_spects_206.mat
# We have 2005 syllables in the first class and 648 in the second class
# All spectrograms were zero padded to equally have 257 time bins.
# We get 2.0 errors in a test set of 1327 syllables.
# Error rate is: 0.00150715900528
# Comparing syllable_spects_305.mat with syllable_spects_204.mat
# We have 2005 syllables in the first class and 2017 in the second class
# All spectrograms were zero padded to equally have 42 time bins.
# We get 3.0 errors in a test set of 2012 syllables.
# Error rate is: 0.00149105367793
# Comparing syllable_spects_305.mat with syllable_spects_1.mat
# We have 2005 syllables in the first class and 1678 in the second class
# All spectrograms were zero padded to equally have 24 time bins.
# We get 3.0 errors in a test set of 1842 syllables.
# Error rate is: 0.00162866449511
# Comparing syllable_spects_305.mat with syllable_spects_0.mat
# We have 2005 syllables in the first class and 2009 in the second class
# All spectrograms were zero padded to equally have 24 time bins.
# We get 3.0 errors in a test set of 2008 syllables.
# Error rate is: 0.00149402390438
# Comparing syllable_spects_305.mat with syllable_spects_205.mat
# We have 2005 syllables in the first class and 2001 in the second class
# All spectrograms were zero padded to equally have 225 time bins.
# We get 33.0 errors in a test set of 2004 syllables.
# Error rate is: 0.0164670658683
# Comparing syllable_spects_305.mat with syllable_spects_201.mat
# We have 2005 syllables in the first class and 2001 in the second class
# All spectrograms were zero padded to equally have 306 time bins.
# We get 8.0 errors in a test set of 2004 syllables.
# Error rate is: 0.00399201596806
# Comparing syllable_spects_305.mat with syllable_spects_4.mat
# We have 2005 syllables in the first class and 2000 in the second class
# All spectrograms were zero padded to equally have 24 time bins.
# We get 4.0 errors in a test set of 2003 syllables.
# Error rate is: 0.00199700449326
# Comparing syllable_spects_305.mat with syllable_spects_5.mat
# We have 2005 syllables in the first class and 2005 in the second class
# All spectrograms were zero padded to equally have 38 time bins.
# We get 5.0 errors in a test set of 2006 syllables.
# Error rate is: 0.0024925224327
# Comparing syllable_spects_305.mat with syllable_spects_200.mat
# We have 2005 syllables in the first class and 2035 in the second class
# All spectrograms were zero padded to equally have 40 time bins.
# We get 3.0 errors in a test set of 2021 syllables.
# Error rate is: 0.00148441365661
# Comparing syllable_spects_305.mat with syllable_spects_7.mat
# We have 2005 syllables in the first class and 2001 in the second class
# All spectrograms were zero padded to equally have 120 time bins.
# We get 17.0 errors in a test set of 2004 syllables.
# Error rate is: 0.00848303393214
# Comparing syllable_spects_305.mat with syllable_spects_404.mat
# We have 2005 syllables in the first class and 1089 in the second class
# All spectrograms were zero padded to equally have 199 time bins.
# We get 10.0 errors in a test set of 1548 syllables.
# Error rate is: 0.00645994832041
# Comparing syllable_spects_305.mat with syllable_spects_6.mat
# We have 2005 syllables in the first class and 2000 in the second class
# All spectrograms were zero padded to equally have 176 time bins.
# We get 5.0 errors in a test set of 2003 syllables.
# Error rate is: 0.00249625561658
# Comparing syllable_spects_305.mat with syllable_spects_203.mat
# We have 2005 syllables in the first class and 2004 in the second class
# All spectrograms were zero padded to equally have 27 time bins.
# We get 4.0 errors in a test set of 2005 syllables.
# Error rate is: 0.00199501246883
# Comparing syllable_spects_306.mat with syllable_spects_500.mat
# We have 2007 syllables in the first class and 2014 in the second class
# All spectrograms were zero padded to equally have 47 time bins.
# We get 15.0 errors in a test set of 2011 syllables.
# Error rate is: 0.00745897563401
# Comparing syllable_spects_306.mat with syllable_spects_302.mat
# We have 2007 syllables in the first class and 1092 in the second class
# All spectrograms were zero padded to equally have 40 time bins.
# We get 0.0 errors in a test set of 1550 syllables.
# Error rate is: 0.0
# Comparing syllable_spects_306.mat with syllable_spects_303.mat
# We have 2007 syllables in the first class and 2010 in the second class
# All spectrograms were zero padded to equally have 40 time bins.
# We get 2.0 errors in a test set of 2009 syllables.
# Error rate is: 0.000995520159283
# Comparing syllable_spects_306.mat with syllable_spects_301.mat
# We have 2007 syllables in the first class and 2004 in the second class
# All spectrograms were zero padded to equally have 40 time bins.
# We get 6.0 errors in a test set of 2006 syllables.
# Error rate is: 0.00299102691924
# Comparing syllable_spects_306.mat with syllable_spects_300.mat
# We have 2007 syllables in the first class and 2018 in the second class
# All spectrograms were zero padded to equally have 40 time bins.
# We get 14.0 errors in a test set of 2013 syllables.
# Error rate is: 0.00695479384004
# Comparing syllable_spects_306.mat with syllable_spects_207.mat
# We have 2007 syllables in the first class and 2004 in the second class
# All spectrograms were zero padded to equally have 220 time bins.
# We get 11.0 errors in a test set of 2006 syllables.
# Error rate is: 0.00548354935194
# Comparing syllable_spects_306.mat with syllable_spects_2.mat
# We have 2007 syllables in the first class and 904 in the second class
# All spectrograms were zero padded to equally have 43 time bins.
# We get 1.0 errors in a test set of 1456 syllables.
# Error rate is: 0.000686813186813
# Comparing syllable_spects_306.mat with syllable_spects_401.mat
# We have 2007 syllables in the first class and 157 in the second class
# All spectrograms were zero padded to equally have 197 time bins.
# We get 3.0 errors in a test set of 1083 syllables.
# Error rate is: 0.00277008310249
# Comparing syllable_spects_306.mat with syllable_spects_400.mat
# We have 2007 syllables in the first class and 2004 in the second class
# All spectrograms were zero padded to equally have 45 time bins.
# We get 1.0 errors in a test set of 2006 syllables.
# Error rate is: 0.00049850448654
# Comparing syllable_spects_306.mat with syllable_spects_3.mat
# We have 2007 syllables in the first class and 2001 in the second class
# All spectrograms were zero padded to equally have 225 time bins.
# We get 27.0 errors in a test set of 2005 syllables.
# Error rate is: 0.0134663341646
# Comparing syllable_spects_306.mat with syllable_spects_206.mat
# We have 2007 syllables in the first class and 648 in the second class
# All spectrograms were zero padded to equally have 257 time bins.
# We get 2.0 errors in a test set of 1328 syllables.
# Error rate is: 0.00150602409639
# Comparing syllable_spects_306.mat with syllable_spects_204.mat
# We have 2007 syllables in the first class and 2017 in the second class
# All spectrograms were zero padded to equally have 42 time bins.
# We get 1.0 errors in a test set of 2013 syllables.
# Error rate is: 0.000496770988574
# Comparing syllable_spects_306.mat with syllable_spects_1.mat
# We have 2007 syllables in the first class and 1678 in the second class
# All spectrograms were zero padded to equally have 40 time bins.
# We get 2.0 errors in a test set of 1843 syllables.
# Error rate is: 0.00108518719479
# Comparing syllable_spects_306.mat with syllable_spects_0.mat
# ...
# We get 11.0 errors in a test set of 1554 syllables.
# Error rate is: 0.00707850707851
# Comparing syllable_spects_204.mat with syllable_spects_6.mat
# We have 2017 syllables in the first class and 2000 in the second class
# All spectrograms were zero padded to equally have 176 time bins.
# We get 3.0 errors in a test set of 2009 syllables.
# Error rate is: 0.00149328023892
# Comparing syllable_spects_204.mat with syllable_spects_203.mat
# We have 2017 syllables in the first class and 2004 in the second class
# All spectrograms were zero padded to equally have 42 time bins.
# We get 4.0 errors in a test set of 2011 syllables.
# Error rate is: 0.00198906016907
# Comparing syllable_spects_1.mat with syllable_spects_0.mat
# We have 1678 syllables in the first class and 2009 in the second class
# All spectrograms were zero padded to equally have 21 time bins.
# We get 1.0 errors in a test set of 1844 syllables.
# Error rate is: 0.000542299349241
# Comparing syllable_spects_1.mat with syllable_spects_205.mat
# We have 1678 syllables in the first class and 2001 in the second class
# All spectrograms were zero padded to equally have 225 time bins.
# We get 32.0 errors in a test set of 1840 syllables.
# Error rate is: 0.0173913043478
# Comparing syllable_spects_1.mat with syllable_spects_201.mat
# We have 1678 syllables in the first class and 2001 in the second class
# All spectrograms were zero padded to equally have 306 time bins.
# We get 8.0 errors in a test set of 1840 syllables.
# Error rate is: 0.00434782608696
# Comparing syllable_spects_1.mat with syllable_spects_4.mat
# We have 1678 syllables in the first class and 2000 in the second class
# All spectrograms were zero padded to equally have 18 time bins.
# We get 0.0 errors in a test set of 1839 syllables.
# Error rate is: 0.0
# Comparing syllable_spects_1.mat with syllable_spects_5.mat
# We have 1678 syllables in the first class and 2005 in the second class
# All spectrograms were zero padded to equally have 38 time bins.
# We get 1.0 errors in a test set of 1842 syllables.
# Error rate is: 0.000542888165038
# Comparing syllable_spects_1.mat with syllable_spects_200.mat
# We have 1678 syllables in the first class and 2035 in the second class
# All spectrograms were zero padded to equally have 40 time bins.
# We get 0.0 errors in a test set of 1857 syllables.
# Error rate is: 0.0
# Comparing syllable_spects_1.mat with syllable_spects_7.mat
# We have 1678 syllables in the first class and 2001 in the second class
# All spectrograms were zero padded to equally have 120 time bins.
# We get 15.0 errors in a test set of 1840 syllables.
# Error rate is: 0.00815217391304
# Comparing syllable_spects_1.mat with syllable_spects_404.mat
# We have 1678 syllables in the first class and 1089 in the second class
# All spectrograms were zero padded to equally have 199 time bins.
# We get 10.0 errors in a test set of 1384 syllables.
# Error rate is: 0.00722543352601
# Comparing syllable_spects_1.mat with syllable_spects_6.mat
# We have 1678 syllables in the first class and 2000 in the second class
# All spectrograms were zero padded to equally have 176 time bins.
# We get 64.0 errors in a test set of 1839 syllables.
# Error rate is: 0.0348015225666
# Comparing syllable_spects_1.mat with syllable_spects_203.mat
# We have 1678 syllables in the first class and 2004 in the second class
# All spectrograms were zero padded to equally have 27 time bins.
# We get 1.0 errors in a test set of 1841 syllables.
# Error rate is: 0.000543183052689
# Comparing syllable_spects_0.mat with syllable_spects_205.mat
# We have 2009 syllables in the first class and 2001 in the second class
# All spectrograms were zero padded to equally have 225 time bins.
# We get 32.0 errors in a test set of 2006 syllables.
# Error rate is: 0.0159521435693
# Comparing syllable_spects_0.mat with syllable_spects_201.mat
# We have 2009 syllables in the first class and 2001 in the second class
# All spectrograms were zero padded to equally have 306 time bins.
# We get 5.0 errors in a test set of 2006 syllables.
# Error rate is: 0.0024925224327
# Comparing syllable_spects_0.mat with syllable_spects_4.mat
# We have 2009 syllables in the first class and 2000 in the second class
# All spectrograms were zero padded to equally have 21 time bins.
# We get 3.0 errors in a test set of 2005 syllables.
# Error rate is: 0.00149625935162
# Comparing syllable_spects_0.mat with syllable_spects_5.mat
# We have 2009 syllables in the first class and 2005 in the second class
# All spectrograms were zero padded to equally have 38 time bins.
# We get 3.0 errors in a test set of 2008 syllables.
# Error rate is: 0.00149402390438
# Comparing syllable_spects_0.mat with syllable_spects_200.mat
# We have 2009 syllables in the first class and 2035 in the second class
# All spectrograms were zero padded to equally have 40 time bins.
# We get 1.0 errors in a test set of 2023 syllables.
# Error rate is: 0.000494315373208
# Comparing syllable_spects_0.mat with syllable_spects_7.mat
# We have 2009 syllables in the first class and 2001 in the second class
# All spectrograms were zero padded to equally have 120 time bins.
# We get 12.0 errors in a test set of 2006 syllables.
# Error rate is: 0.00598205383848
# Comparing syllable_spects_0.mat with syllable_spects_404.mat
# We have 2009 syllables in the first class and 1089 in the second class
# All spectrograms were zero padded to equally have 199 time bins.
# We get 9.0 errors in a test set of 1550 syllables.
# Error rate is: 0.0058064516129
# Comparing syllable_spects_0.mat with syllable_spects_6.mat
# We have 2009 syllables in the first class and 2000 in the second class
# All spectrograms were zero padded to equally have 176 time bins.
# We get 2.0 errors in a test set of 2005 syllables.
# Error rate is: 0.000997506234414
# Comparing syllable_spects_0.mat with syllable_spects_203.mat
# We have 2009 syllables in the first class and 2004 in the second class
# All spectrograms were zero padded to equally have 27 time bins.
# We get 1.0 errors in a test set of 2007 syllables.
# Error rate is: 0.000498256103637
# Comparing syllable_spects_205.mat with syllable_spects_201.mat
# We have 2001 syllables in the first class and 2001 in the second class
# All spectrograms were zero padded to equally have 306 time bins.
# We get 41.0 errors in a test set of 2002 syllables.
# Error rate is: 0.0204795204795
# Comparing syllable_spects_205.mat with syllable_spects_4.mat
# We have 2001 syllables in the first class and 2000 in the second class
# All spectrograms were zero padded to equally have 225 time bins.
# We get 33.0 errors in a test set of 2001 syllables.
# Error rate is: 0.0164917541229
# Comparing syllable_spects_205.mat with syllable_spects_5.mat
# We have 2001 syllables in the first class and 2005 in the second class
# All spectrograms were zero padded to equally have 225 time bins.
# We get 33.0 errors in a test set of 2004 syllables.
# Error rate is: 0.0164670658683
# Comparing syllable_spects_205.mat with syllable_spects_200.mat
# We have 2001 syllables in the first class and 2035 in the second class
# All spectrograms were zero padded to equally have 225 time bins.
# We get 38.0 errors in a test set of 2019 syllables.
# Error rate is: 0.0188211986132
# Comparing syllable_spects_205.mat with syllable_spects_7.mat
# We have 2001 syllables in the first class and 2001 in the second class
# All spectrograms were zero padded to equally have 225 time bins.
# We get 44.0 errors in a test set of 2002 syllables.
# Error rate is: 0.021978021978
# Comparing syllable_spects_205.mat with syllable_spects_404.mat
# We have 2001 syllables in the first class and 1089 in the second class
# All spectrograms were zero padded to equally have 225 time bins.
# We get 8.0 errors in a test set of 1546 syllables.
# Error rate is: 0.00517464424321
# Comparing syllable_spects_205.mat with syllable_spects_6.mat
# We have 2001 syllables in the first class and 2000 in the second class
# All spectrograms were zero padded to equally have 225 time bins.
# We get 41.0 errors in a test set of 2001 syllables.
# Error rate is: 0.0204897551224
# Comparing syllable_spects_205.mat with syllable_spects_203.mat
# We have 2001 syllables in the first class and 2004 in the second class
# All spectrograms were zero padded to equally have 225 time bins.
# We get 33.0 errors in a test set of 2003 syllables.
# Error rate is: 0.0164752870694
# Comparing syllable_spects_201.mat with syllable_spects_4.mat
# We have 2001 syllables in the first class and 2000 in the second class
# All spectrograms were zero padded to equally have 306 time bins.
# We get 7.0 errors in a test set of 2001 syllables.
# Error rate is: 0.00349825087456
# Comparing syllable_spects_201.mat with syllable_spects_5.mat
# We have 2001 syllables in the first class and 2005 in the second class
# All spectrograms were zero padded to equally have 306 time bins.
# We get 12.0 errors in a test set of 2004 syllables.
# Error rate is: 0.0059880239521
# Comparing syllable_spects_201.mat with syllable_spects_200.mat
# We have 2001 syllables in the first class and 2035 in the second class
# All spectrograms were zero padded to equally have 306 time bins.
# We get 10.0 errors in a test set of 2019 syllables.
# Error rate is: 0.00495294700347
# Comparing syllable_spects_201.mat with syllable_spects_7.mat
# We have 2001 syllables in the first class and 2001 in the second class
# All spectrograms were zero padded to equally have 306 time bins.
# We get 17.0 errors in a test set of 2002 syllables.
# Error rate is: 0.00849150849151
# Comparing syllable_spects_201.mat with syllable_spects_404.mat
# We have 2001 syllables in the first class and 1089 in the second class
# All spectrograms were zero padded to equally have 306 time bins.
# We get 11.0 errors in a test set of 1546 syllables.
# Error rate is: 0.00711513583441
# Comparing syllable_spects_201.mat with syllable_spects_6.mat
# We have 2001 syllables in the first class and 2000 in the second class
# All spectrograms were zero padded to equally have 306 time bins.
# We get 10.0 errors in a test set of 2001 syllables.
# Error rate is: 0.00499750124938
# Comparing syllable_spects_201.mat with syllable_spects_203.mat
# We have 2001 syllables in the first class and 2004 in the second class
# All spectrograms were zero padded to equally have 306 time bins.
# We get 9.0 errors in a test set of 2003 syllables.
# Error rate is: 0.00449326010984
# Comparing syllable_spects_4.mat with syllable_spects_5.mat
# We have 2000 syllables in the first class and 2005 in the second class
# All spectrograms were zero padded to equally have 38 time bins.
# We get 16.0 errors in a test set of 2003 syllables.
# Error rate is: 0.00798801797304
# Comparing syllable_spects_4.mat with syllable_spects_200.mat
# We have 2000 syllables in the first class and 2035 in the second class
# All spectrograms were zero padded to equally have 40 time bins.
# We get 3.0 errors in a test set of 2018 syllables.
# Error rate is: 0.00148662041625
# Comparing syllable_spects_4.mat with syllable_spects_7.mat
# We have 2000 syllables in the first class and 2001 in the second class
# All spectrograms were zero padded to equally have 120 time bins.
# We get 14.0 errors in a test set of 2001 syllables.
# Error rate is: 0.00699650174913
# Comparing syllable_spects_4.mat with syllable_spects_404.mat
# We have 2000 syllables in the first class and 1089 in the second class
# All spectrograms were zero padded to equally have 199 time bins.
# We get 8.0 errors in a test set of 1545 syllables.
# Error rate is: 0.00517799352751
# Comparing syllable_spects_4.mat with syllable_spects_6.mat
# We have 2000 syllables in the first class and 2000 in the second class
# All spectrograms were zero padded to equally have 176 time bins.
# We get 73.0 errors in a test set of 2000 syllables.
# Error rate is: 0.0365
# Comparing syllable_spects_4.mat with syllable_spects_203.mat
# We have 2000 syllables in the first class and 2004 in the second class
# All spectrograms were zero padded to equally have 27 time bins.
# We get 9.0 errors in a test set of 2002 syllables.
# Error rate is: 0.0044955044955
# Comparing syllable_spects_5.mat with syllable_spects_200.mat
# We have 2005 syllables in the first class and 2035 in the second class
# All spectrograms were zero padded to equally have 40 time bins.
# We get 18.0 errors in a test set of 2021 syllables.
# Error rate is: 0.00890648193963
# Comparing syllable_spects_5.mat with syllable_spects_7.mat
# We have 2005 syllables in the first class and 2001 in the second class
# All spectrograms were zero padded to equally have 120 time bins.
# We get 30.0 errors in a test set of 2004 syllables.
# Error rate is: 0.0149700598802
# Comparing syllable_spects_5.mat with syllable_spects_404.mat
# We have 2005 syllables in the first class and 1089 in the second class
# All spectrograms were zero padded to equally have 199 time bins.
# We get 10.0 errors in a test set of 1548 syllables.
# Error rate is: 0.00645994832041
# Comparing syllable_spects_5.mat with syllable_spects_6.mat
# We have 2005 syllables in the first class and 2000 in the second class
# All spectrograms were zero padded to equally have 176 time bins.
# We get 95.0 errors in a test set of 2003 syllables.
# Error rate is: 0.0474288567149
# Comparing syllable_spects_5.mat with syllable_spects_203.mat
# We have 2005 syllables in the first class and 2004 in the second class
# All spectrograms were zero padded to equally have 38 time bins.
# We get 4.0 errors in a test set of 2005 syllables.
# Error rate is: 0.00199501246883
# Comparing syllable_spects_200.mat with syllable_spects_7.mat
# We have 2035 syllables in the first class and 2001 in the second class
# All spectrograms were zero padded to equally have 120 time bins.
# We get 22.0 errors in a test set of 2019 syllables.
# Error rate is: 0.0108964834076
# Comparing syllable_spects_200.mat with syllable_spects_404.mat
# We have 2035 syllables in the first class and 1089 in the second class
# All spectrograms were zero padded to equally have 199 time bins.
# We get 10.0 errors in a test set of 1563 syllables.
# Error rate is: 0.00639795265515
# Comparing syllable_spects_200.mat with syllable_spects_6.mat
# We have 2035 syllables in the first class and 2000 in the second class
# All spectrograms were zero padded to equally have 176 time bins.
# We get 35.0 errors in a test set of 2018 syllables.
# Error rate is: 0.0173439048563
# Comparing syllable_spects_200.mat with syllable_spects_203.mat
# We have 2035 syllables in the first class and 2004 in the second class
# All spectrograms were zero padded to equally have 40 time bins.
# We get 0.0 errors in a test set of 2020 syllables.
# Error rate is: 0.0
# Comparing syllable_spects_7.mat with syllable_spects_404.mat
# We have 2001 syllables in the first class and 1089 in the second class
# All spectrograms were zero padded to equally have 199 time bins.
# We get 8.0 errors in a test set of 1546 syllables.
# Error rate is: 0.00517464424321
# Comparing syllable_spects_7.mat with syllable_spects_6.mat
# We have 2001 syllables in the first class and 2000 in the second class
# All spectrograms were zero padded to equally have 176 time bins.
# We get 56.0 errors in a test set of 2001 syllables.
# Error rate is: 0.0279860069965
# Comparing syllable_spects_7.mat with syllable_spects_203.mat
# We have 2001 syllables in the first class and 2004 in the second class
# All spectrograms were zero padded to equally have 120 time bins.
# We get 19.0 errors in a test set of 2003 syllables.
# Error rate is: 0.00948577134299
# Comparing syllable_spects_404.mat with syllable_spects_6.mat
# We have 1089 syllables in the first class and 2000 in the second class
# All spectrograms were zero padded to equally have 199 time bins.
# We get 8.0 errors in a test set of 1545 syllables.
# Error rate is: 0.00517799352751
# Comparing syllable_spects_404.mat with syllable_spects_203.mat
# We have 1089 syllables in the first class and 2004 in the second class
# All spectrograms were zero padded to equally have 199 time bins.
# We get 11.0 errors in a test set of 1547 syllables.
# Error rate is: 0.0071105365223
# Comparing syllable_spects_6.mat with syllable_spects_203.mat
# We have 2000 syllables in the first class and 2004 in the second class
# All spectrograms were zero padded to equally have 176 time bins.
# We get 3.0 errors in a test set of 2002 syllables.
# Error rate is: 0.0014985014985

# %%
plt.figure()
plt.imshow(ErrMat)
plt.show()

# %%
cpio.savemat('ErrMat.mat' ,{'ErrMat':ErrMat})

# %%
range(3,15)

# %%
import numpy as np
import scipy.io as cpio
import os
import matplotlib.pyplot as plt
import glob

# %%
ErrMat = cpio.loadmat('ErrMat.mat')

# %%
matfiles = glob.glob('*.mat')[1:]
filenum = [int(k[16:-4]) for k in matfiles]

# %%
print(filenum)
# Out:
# [8, 9, 208, 308, 304, 305, 306, 500, 302, 303, 301, 300, 207, 2, 401, 400, 3, 206, 204, 1, 0, 205, 201, 4, 5, 200, 7, 404, 6, 203]

# %%
cpio.savemat('filenum.mat' ,{'filenum':filenum})
